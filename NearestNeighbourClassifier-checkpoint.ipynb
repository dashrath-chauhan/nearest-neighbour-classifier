# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
#Training sets, containing points and labels(colors)
setX = []
setY = []
colors = ['red','blue','black']
for i in range(20):
    setX.append([round(random.uniform(0,9), 1),round(random.uniform(0,9), 1)])
    setY.append(random.choice(colors))
testPoint = [round(random.uniform(0,9), 1),round(random.uniform(0,9), 1)]
print(setX)
TestSet = np.array(testPoint)
X_Train = np.array(setX)
Y_Train = np.array(setY)
# Out:
# [[4.4, 1.8], [6.4, 3.7], [7.9, 4.4], [4.4, 4.8], [5.7, 8.0], [5.3, 7.0], [2.1, 5.4], [3.7, 1.3], [2.5, 3.8], [6.2, 2.9], [3.0, 7.3], [2.8, 5.2], [3.9, 2.8], [1.4, 8.2], [7.3, 7.0], [0.1, 6.0], [7.7, 1.0], [3.8, 5.9], [8.9, 0.6], [8.7, 8.0]]

# %%
#print(X_Train[5,0])
#print(Y_Train[5])
print(X_Train[:,0])
print(X_Train[:,1])
# Out:
# [4.4 6.4 7.9 4.4 5.7 5.3 2.1 3.7 2.5 6.2 3.  2.8 3.9 1.4 7.3 0.1 7.7 3.8
#  8.9 8.7]
# [1.8 3.7 4.4 4.8 8.  7.  5.4 1.3 3.8 2.9 7.3 5.2 2.8 8.2 7.  6.  1.  5.9
#  0.6 8. ]

# %%
plt.figure()
plt.scatter(X_Train[:, 0], X_Train[:, 1], s=170, color = Y_Train[:])
plt.scatter(TestSet[0], TestSet[1], s=170, color = 'green')
plt.title('Before Classification')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#function that classifies the nearest neighbour

def dist(x,y):
    return np.sqrt(np.sum((x-y)**2))

# %%
#for each point in X_Train, we compute the distance to TestSet
num = len(X_Train)
distance = np.zeros(num)
for i in range(num):
    distance[i] = dist(X_Train[i], TestSet)
print(distance)
# Out:
# [4.38406204 1.62788206 0.64031242 3.10161248 3.58468967 3.04138127
#  5.42309875 5.23450093 5.11957029 2.38537209 5.1        4.70956474
#  4.1677332  6.93541635 2.10950231 7.48131005 3.90512484 3.83275358
#  4.52216762 3.32415403]

# %%
#choose the point in X_train with minimum distance to the new test point
minimum = np.around(np.argmin(distance), decimals=1)
print(Y_Train[minimum])
plt.figure()
plt.scatter(X_Train[:, 0], X_Train[:, 1], s=170, color = Y_Train[:])
plt.scatter(TestSet[0], TestSet[1], s=170, color = Y_Train[minimum])
plt.title('After Classification')
plt.show()
# Out:
# blue
# <img src="data:image/png;base64,..." width="640">
